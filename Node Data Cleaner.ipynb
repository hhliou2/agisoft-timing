# %%
# imports
import pandas as pd
import numpy as np

# %%
# Read in file
node_info = pd.read_csv('nodeInfo.csv')

# %%
# Set hostname as index
node_info = node_info.set_index('hostname')

# %%
node_info
# Out:
#                    error_count  priority  node_id     version  \
# hostname
# sme2d-1-0.local              0         0        0  1.4.5.7354
# sme2d-0-0.local              0         0        1  1.4.5.7354
# sme2d-0-1.local              0         0        2  1.4.5.7354
# sme2d.local                  0         0        3  1.4.5.7354
# sme2d-1-1.local              0         0        4  1.4.5.7354
# cisa3-sfm3                   0         0        5  1.4.5.7354
# cisa3-sfm2                   0         0        6  1.4.5.7354
# eklo-ws                      0         0        7  1.4.5.7354
# wavelet2-0                   0         0        8  1.4.5.7354
# wavelet2-0                 420         0        9  1.4.5.7354
# eklo-ws                      0         0       10  1.4.5.7354
# wavelet2-0                   0         0       11  1.4.5.7354
# sme2d.local                  0         0       12  1.4.5.7354
# sme2d.local                  0         0       13  1.4.5.7354
# ...

# %%
# All columns
list(node_info)
# Out:
# ['error_count',
#  'priority',
#  'node_id',
#  'version',
#  'hostaddr',
#  'task_name',
#  'status',
#  'error_message',
#  'progress',
#  'task_params',
#  'time_disconnected',
#  'time_connected',
#  'batch_id',
#  'error_batch_id',
#  'error_time']

# %%
node_info.to_csv('CleanedInfo.csv')
